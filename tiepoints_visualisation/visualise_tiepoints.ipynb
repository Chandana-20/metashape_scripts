# %% [markdown]
# Summary :
# The pixel coordinates in the images which corresponds to tie points are marked green. This is performed for better visualisation of location of tie points. The tie points location data is extracted from metashape using metashape python api code - (extract_tiepoints_2D.py).

# %%
import csv
import os
import cv2
import numpy as np
from collections import defaultdict

# %%
def read_tiepoints(csv_path):
    tiepoints_by_image = defaultdict(list)
    
    with open(csv_path, 'r') as f:
        csv_reader = csv.DictReader(f)
        for row in csv_reader:
            camera = row['Camera']
            u = float(row['u'])
            v = float(row['v'])
            tiepoints_by_image[camera].append((u, v))
    
    return tiepoints_by_image

# %%
def draw_tiepoints_on_images(tiepoints_by_image, images_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for camera, points in tiepoints_by_image.items():
        # Try different common image extensions
        image_path = None
        for ext in ['.jpg', '.jpeg', '.png', '.tif', '.tiff']:
            potential_path = os.path.join(images_folder, camera + ext)
            if os.path.exists(potential_path):
                image_path = potential_path
                break
        
        # Check if image exists
        if not image_path:
            print(f"Image for camera {camera} not found. Skipping.")
            continue
        
        # Load the image
        img = cv2.imread(image_path)
        if img is None:
            print(f"Failed to load image {image_path}. Skipping.")
            continue
        
        # Draw tie points as small red dots
        for u, v in points:
            # Convert to integer pixel coordinates
            x, y = int(round(u)), int(round(v))
            # Draw a small red circle (BGR format: 0,0,255 = red)
            cv2.circle(img, (x, y), 20, (0, 255, 0), -1)
        
        # Save the image with tie points drawn
        output_path = os.path.join(output_folder, f"{camera}_tiepoints.jpg")
        cv2.imwrite(output_path, img)
        print(f"Saved image with tie points: {output_path}")

# %%
if __name__ == "__main__":
    # Paths - update these to match your environment
    csv_path = r"D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\tiepoints_uv_TwoMeters.csv"
    images_folder = r"D:\Chandana\ArUco_Accuracy\calibration_images\two_mtr"
    output_folder = r"D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints"
    
    # Read tie points and group by image
    tiepoints_by_image = read_tiepoints(csv_path)
    
    # Draw tie points on images
    draw_tiepoints_on_images(tiepoints_by_image, images_folder, output_folder)
# Out:
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0888_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0893_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0894_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0895_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0896_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0897_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0898_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0899_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0900_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0901_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0902_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0903_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0904_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0905_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0906_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0907_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0908_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0909_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0911_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0912_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0913_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0914_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0915_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0916_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0917_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0918_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0919_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0920_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0921_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0922_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0923_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0924_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0925_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0926_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0927_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0928_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0931_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0932_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0933_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0934_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0935_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0936_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0937_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0938_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0939_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0941_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0942_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0943_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0944_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0945_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0946_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0947_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0948_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0949_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0950_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0951_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0952_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0953_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0954_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0955_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0956_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0957_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0958_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0959_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0960_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0961_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0962_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0963_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0964_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0965_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0966_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0967_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0968_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0969_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0970_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0971_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0972_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0973_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0974_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0975_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0976_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0977_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0978_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0979_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0980_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0981_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0982_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0983_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0984_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0985_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0986_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0987_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0988_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0989_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0990_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0991_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0992_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0993_tiepoints.jpg
# Saved image with tie points: D:\Chandana\ArUco_Accuracy\Scripts\tiepoints_visualisation\output_images_with_tiepoints\IMG_0994_tiepoints.jpg
